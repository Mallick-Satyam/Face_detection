# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil=Image.open("thor.jpg")

# %%
arr=np.array(pil)

# %%
arr.shape
# Out:
# (246, 220, 3)

# %%
work=arr.copy()

# %%
pit=Image.open("rgb.jpg")

# %%
brr=np.array(pit)

# %%
brr.shape
# Out:
# (194, 259, 3)

# %%
pit
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194 at 0x1E205249400>

# %%
red=brr[100:150,:300]

# %%
plt.imshow(red)

# %%
work[:,:,[1,2]]=0

# %%
plt.imshow(work)

# %%
plt.imshow(work)

# %%
work[:,:,[1,2]]=155

# %%
plt.imshow(work)

# %%
grey=arr.mean(axis=2)

# %%
plt.imshow(grey)
